# %%
import pandas as pd
import json

# %%
# Load your Excel file
file_path = 'Cases_Report___General_Analysis - 2024-08-27.xlsx'
df = pd.read_excel(file_path)

# %%
# Filter out only the necessary columns and data
# Adjust this according to your actual data structure
columns_needed = ['Date Closed', 'Program Name', 'Legal Problem', 'Funding Code(s)', 
                  'Case Close Reason', 'Age at Intake', 'Gender', 'Race', 'Total Number Helped']
df_filtered = df[columns_needed]

# %%
df_filtered.head(10)
# Out:
#   Date Closed Program Name                Legal Problem Funding Code(s)  \
# 0  2024-08-14  Intake Dept  01 Bankruptcy/Debtor Relief         14 IOTA
# 1  2024-08-14  Intake Dept  01 Bankruptcy/Debtor Relief         14 IOTA
# 2  2024-08-10  Intake Dept  01 Bankruptcy/Debtor Relief         14 IOTA
# 3  2024-08-06  Intake Dept  01 Bankruptcy/Debtor Relief         14 IOTA
# 4  2024-07-25  Intake Dept  01 Bankruptcy/Debtor Relief         14 IOTA
# 5  2024-07-25  Intake Dept  01 Bankruptcy/Debtor Relief         14 IOTA
# 6  2024-07-10  Intake Dept  01 Bankruptcy/Debtor Relief         14 IOTA
# 7  2024-07-10  Intake Dept  01 Bankruptcy/Debtor Relief         14 IOTA
# 8  2024-06-28  Intake Dept  01 Bankruptcy/Debtor Relief   16 Title IIIB
# 9  2024-06-28  Intake Dept  01 Bankruptcy/Debtor Relief         14 IOTA
#
#       Case Close Reason  Age at Intake  Gender                    Race  \
# 0  A Counsel and Advice             48  Female                   White
# ...

# %%
# Convert the DataFrame to JSON
json_data = df_filtered.to_dict(orient='records')

# Save to a JSON file
with open('data.json', 'w') as json_file:
    json.dump(json_data, json_file)
